# %%
# %pip install -r requirements.txt

# %%
import sys
from pathlib import Path

SRC_DIR = Path.cwd() / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

import importlib
from envegecimiento import external_bbox_annotator, run_annotation

importlib.reload(external_bbox_annotator)
importlib.reload(run_annotation)


result = run_annotation.run(
    "drive",
    num_images=1,
    fail_on_upload_error=False)

result
# Out:
# Seleccion (drive_remote_session): 44323.png
# {'image_id': '44323.png',
#  'image_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\.drive_cache\\1LN7VNGPRz6kZN5a_VvbOCkbMXG6y7F3u\\44323.png',
#  'image_meta': {'filename': '44323.png',
#   'stem': '44323',
#   'extension': '.png',
#   'file_size_bytes': 1455123,
#   'width_px': 1024,
#   'height_px': 1024,
#   'modified_at': '2026-04-27T00:51:51Z'},
#  'created_at': '2026-04-27T00:51:52Z',
#  'global': {'label_id': 0, 'score': 0, 'ethnicity': 'Niño joven asiatico'},
#  'regions': {'frente': {'label_id': 1,
#    'region_name': 'Frente',
#    'region_alias': 'Frente',
#    'expected_boxes': 1,
#    'slots': [{'box_index': 1,
#      'bbox': None,
#      'score': None,
#      'ethnicity': 'Niño joven asiatico',
#      'omitted': True,
#      'slot_status': 'Missing'}]},
#   'glabela_entrecejo': {'label_id': 2,
#    'region_name': 'Glabela / Entrecejo',
#    'region_alias': 'Entrecejo',
#    'expected_boxes': 1,
#    'slots': [{'box_index': 1,
#      'bbox': {'x': 457, 'y': 340, 'w': 132, 'h': 119},
#      'score': 0,
#      'ethnicity': 'Niño joven asiatico',
#      'omitted': False,
#      'slot_status': 'Annotated'}]},
#   'patas_de_gallo': {'label_id': 3,
#    'region_name': 'Patas de gallo',
#    'region_alias': 'Patas de gallo',
#    'expected_boxes': 2,
#    'slots': [{'box_index': 1,
#      'bbox': None,
#      'score': None,
#      'ethnicity': 'Niño joven asiatico',
#      'omitted': True,
#      'slot_status': 'Missing'},
#     {'box_index': 2,
#      'bbox': None,
#      'score': None,
#      'ethnicity': 'Niño joven asiatico',
#      'omitted': True,
#      'slot_status': 'Missing'}]},
#   'bajo_ojo_ojeras': {'label_id': 4,
#    'region_name': 'Bajo ojo / Ojeras',
#    'region_alias': 'Ojeras',
#    'expected_boxes': 2,
#    'slots': [{'box_index': 1,
#      'bbox': {'x': 283, 'y': 511, 'w': 169, 'h': 91},
#      'score': 0,
#      'ethnicity': 'Niño joven asiatico',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'box_index': 2,
#      'bbox': {'x': 592, 'y': 513, 'w': 153, 'h': 94},
#      'score': 0,
#      'ethnicity': 'Niño joven asiatico',
#      'omitted': False,
#      'slot_status': 'Annotated'}]},
#   'surcos_nasogenianos': {'label_id': 5,
#    'region_name': 'Surcos Nasogenianos',
#    'region_alias': 'Surcos nasogenianos',
#    'expected_boxes': 2,
#    'slots': [{'box_index': 1,
#      'bbox': {'x': 243, 'y': 609, 'w': 169, 'h': 115},
#      'score': 5,
#      'ethnicity': 'Niño joven asiatico',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'box_index': 2,
#      'bbox': {'x': 602, 'y': 613, 'w': 159, 'h': 111},
#      'score': 5,
#      'ethnicity': 'Niño joven asiatico',
#      'omitted': False,
#      'slot_status': 'Annotated'}]},
#   'labio_superior': {'label_id': 6,
#    'region_name': 'Labio superior',
#    'region_alias': 'Labio superior',
#    'expected_boxes': 1,
#    'slots': [{'box_index': 1,
#      'bbox': {'x': 402, 'y': 650, 'w': 231, 'h': 61},
#      'score': 0,
#      'ethnicity': 'Niño joven asiatico',
#      'omitted': False,
#      'slot_status': 'Annotated'}]},
#   'comisuras_lineas_marioneta': {'label_id': 7,
#    'region_name': 'Comisuras / lineas de marioneta',
#    'region_alias': 'Lineas marioneta',
#    'expected_boxes': 2,
#    'slots': [{'box_index': 1,
#      'bbox': {'x': 257, 'y': 707, 'w': 147, 'h': 188},
#      'score': 0,
#      'ethnicity': 'Niño joven asiatico',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'box_index': 2,
#      'bbox': {'x': 622, 'y': 710, 'w': 126, 'h': 190},
#      'score': 0,
#      'ethnicity': 'Niño joven asiatico',
#      'omitted': False,
#      'slot_status': 'Annotated'}]},
#   'puente_nasal': {'label_id': 8,
#    'region_name': 'Puente Nasal',
#    'region_alias': 'Puente nasal',
#    'expected_boxes': 1,
#    'slots': [{'box_index': 1,
#      'bbox': {'x': 494, 'y': 495, 'w': 69, 'h': 102},
#      'score': 0,
#      'ethnicity': 'Niño joven asiatico',
#      'omitted': False,
#      'slot_status': 'Annotated'}]}},
#  'all_slots': [{'label_id': 1,
#    'region_key': 'frente',
#    'region_name': 'Frente',
#    'region_alias': 'Frente',
#    'box_index': 1,
#    'bbox': None,
#    'score': None,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': True,
#    'slot_status': 'Missing'},
#   {'label_id': 2,
#    'region_key': 'glabela_entrecejo',
#    'region_name': 'Glabela / Entrecejo',
#    'region_alias': 'Entrecejo',
#    'box_index': 1,
#    'bbox': {'x': 457, 'y': 340, 'w': 132, 'h': 119},
#    'score': 0,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': False,
#    'slot_status': 'Annotated'},
#   {'label_id': 3,
#    'region_key': 'patas_de_gallo',
#    'region_name': 'Patas de gallo',
#    'region_alias': 'Patas de gallo',
#    'box_index': 1,
#    'bbox': None,
#    'score': None,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': True,
#    'slot_status': 'Missing'},
#   {'label_id': 3,
#    'region_key': 'patas_de_gallo',
#    'region_name': 'Patas de gallo',
#    'region_alias': 'Patas de gallo',
#    'box_index': 2,
#    'bbox': None,
#    'score': None,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': True,
#    'slot_status': 'Missing'},
#   {'label_id': 4,
#    'region_key': 'bajo_ojo_ojeras',
#    'region_name': 'Bajo ojo / Ojeras',
#    'region_alias': 'Ojeras',
#    'box_index': 1,
#    'bbox': {'x': 283, 'y': 511, 'w': 169, 'h': 91},
#    'score': 0,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': False,
#    'slot_status': 'Annotated'},
#   {'label_id': 4,
#    'region_key': 'bajo_ojo_ojeras',
#    'region_name': 'Bajo ojo / Ojeras',
#    'region_alias': 'Ojeras',
#    'box_index': 2,
#    'bbox': {'x': 592, 'y': 513, 'w': 153, 'h': 94},
#    'score': 0,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': False,
#    'slot_status': 'Annotated'},
#   {'label_id': 5,
#    'region_key': 'surcos_nasogenianos',
#    'region_name': 'Surcos Nasogenianos',
#    'region_alias': 'Surcos nasogenianos',
#    'box_index': 1,
#    'bbox': {'x': 243, 'y': 609, 'w': 169, 'h': 115},
#    'score': 5,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': False,
#    'slot_status': 'Annotated'},
#   {'label_id': 5,
#    'region_key': 'surcos_nasogenianos',
#    'region_name': 'Surcos Nasogenianos',
#    'region_alias': 'Surcos nasogenianos',
#    'box_index': 2,
#    'bbox': {'x': 602, 'y': 613, 'w': 159, 'h': 111},
#    'score': 5,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': False,
#    'slot_status': 'Annotated'},
#   {'label_id': 6,
#    'region_key': 'labio_superior',
#    'region_name': 'Labio superior',
#    'region_alias': 'Labio superior',
#    'box_index': 1,
#    'bbox': {'x': 402, 'y': 650, 'w': 231, 'h': 61},
#    'score': 0,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': False,
#    'slot_status': 'Annotated'},
#   {'label_id': 7,
#    'region_key': 'comisuras_lineas_marioneta',
#    'region_name': 'Comisuras / lineas de marioneta',
#    'region_alias': 'Lineas marioneta',
#    'box_index': 1,
#    'bbox': {'x': 257, 'y': 707, 'w': 147, 'h': 188},
#    'score': 0,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': False,
#    'slot_status': 'Annotated'},
#   {'label_id': 7,
#    'region_key': 'comisuras_lineas_marioneta',
#    'region_name': 'Comisuras / lineas de marioneta',
#    'region_alias': 'Lineas marioneta',
#    'box_index': 2,
#    'bbox': {'x': 622, 'y': 710, 'w': 126, 'h': 190},
#    'score': 0,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': False,
#    'slot_status': 'Annotated'},
#   {'label_id': 8,
#    'region_key': 'puente_nasal',
#    'region_name': 'Puente Nasal',
#    'region_alias': 'Puente nasal',
#    'box_index': 1,
#    'bbox': {'x': 494, 'y': 495, 'w': 69, 'h': 102},
#    'score': 0,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': False,
#    'slot_status': 'Annotated'}],
#  '_local_json_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\results\\44323_annotations.json',
#  '_upload': {'ok': True,
#   'status_code': 200,
#   'response_text': 'OK: saved 1 -> 44323.png.json',
#   'remote_filename': '44323.png.json'},
#  '_session_total': 1,
#  '_session_resumed_from_index': 1}

# %%
from envegecimiento.preview_boxes_from_json import show_boxes_from_json

result_preview = show_boxes_from_json(
    r'results\44323_annotations.json',
    show=True)
result_preview
# Out:
# JSON: C:\Users\alejo\OneDrive\Escritorio\Pablo\Profesional\Semillero\protocolo de etiquetado\results\44323_annotations.json
# Imagen original: C:\Users\alejo\OneDrive\Escritorio\Pablo\Profesional\Semillero\protocolo de etiquetado\.drive_cache\1LN7VNGPRz6kZN5a_VvbOCkbMXG6y7F3u\44323.png
# Global: {'label_id': 0, 'score': 0, 'ethnicity': 'Niño joven asiatico'}
#
# Boxes en orden:
# 02. Entrecejo#1 | score=0 | etnicidad=Niño joven asiatico | bbox=(x=457, y=340, w=132, h=119)
# 05. Ojeras#1 | score=0 | etnicidad=Niño joven asiatico | bbox=(x=283, y=511, w=169, h=91)
# 06. Ojeras#2 | score=0 | etnicidad=Niño joven asiatico | bbox=(x=592, y=513, w=153, h=94)
# 07. Surcos nasogenianos#1 | score=5 | etnicidad=Niño joven asiatico | bbox=(x=243, y=609, w=169, h=115)
# 08. Surcos nasogenianos#2 | score=5 | etnicidad=Niño joven asiatico | bbox=(x=602, y=613, w=159, h=111)
# 09. Labio superior#1 | score=0 | etnicidad=Niño joven asiatico | bbox=(x=402, y=650, w=231, h=61)
# 10. Lineas marioneta#1 | score=0 | etnicidad=Niño joven asiatico | bbox=(x=257, y=707, w=147, h=188)
# 11. Lineas marioneta#2 | score=0 | etnicidad=Niño joven asiatico | bbox=(x=622, y=710, w=126, h=190)
# 12. Puente nasal#1 | score=0 | etnicidad=Niño joven asiatico | bbox=(x=494, y=495, w=69, h=102)
#
# Preview guardado en: C:\Users\alejo\OneDrive\Escritorio\Pablo\Profesional\Semillero\protocolo de etiquetado\data_boxes\44323_boxes_preview.jpg
# {'json_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\results\\44323_annotations.json',
#  'image_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\.drive_cache\\1LN7VNGPRz6kZN5a_VvbOCkbMXG6y7F3u\\44323.png',
#  'preview_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\data_boxes\\44323_boxes_preview.jpg',
#  'boxes': [{'order': 2,
#    'label_id': 2,
#    'region_key': 'glabela_entrecejo',
#    'region_name': 'Glabela / Entrecejo',
#    'region_alias': 'Entrecejo',
#    'box_index': 1,
#    'score': 0,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': False,
#    'bbox': {'x': 457, 'y': 340, 'w': 132, 'h': 119}},
#   {'order': 5,
#    'label_id': 4,
#    'region_key': 'bajo_ojo_ojeras',
#    'region_name': 'Bajo ojo / Ojeras',
#    'region_alias': 'Ojeras',
#    'box_index': 1,
#    'score': 0,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': False,
#    'bbox': {'x': 283, 'y': 511, 'w': 169, 'h': 91}},
#   {'order': 6,
#    'label_id': 4,
#    'region_key': 'bajo_ojo_ojeras',
#    'region_name': 'Bajo ojo / Ojeras',
#    'region_alias': 'Ojeras',
#    'box_index': 2,
#    'score': 0,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': False,
#    'bbox': {'x': 592, 'y': 513, 'w': 153, 'h': 94}},
#   {'order': 7,
#    'label_id': 5,
#    'region_key': 'surcos_nasogenianos',
#    'region_name': 'Surcos Nasogenianos',
#    'region_alias': 'Surcos nasogenianos',
#    'box_index': 1,
#    'score': 5,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': False,
#    'bbox': {'x': 243, 'y': 609, 'w': 169, 'h': 115}},
#   {'order': 8,
#    'label_id': 5,
#    'region_key': 'surcos_nasogenianos',
#    'region_name': 'Surcos Nasogenianos',
#    'region_alias': 'Surcos nasogenianos',
#    'box_index': 2,
#    'score': 5,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': False,
#    'bbox': {'x': 602, 'y': 613, 'w': 159, 'h': 111}},
#   {'order': 9,
#    'label_id': 6,
#    'region_key': 'labio_superior',
#    'region_name': 'Labio superior',
#    'region_alias': 'Labio superior',
#    'box_index': 1,
#    'score': 0,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': False,
#    'bbox': {'x': 402, 'y': 650, 'w': 231, 'h': 61}},
#   {'order': 10,
#    'label_id': 7,
#    'region_key': 'comisuras_lineas_marioneta',
#    'region_name': 'Comisuras / lineas de marioneta',
#    'region_alias': 'Lineas marioneta',
#    'box_index': 1,
#    'score': 0,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': False,
#    'bbox': {'x': 257, 'y': 707, 'w': 147, 'h': 188}},
#   {'order': 11,
#    'label_id': 7,
#    'region_key': 'comisuras_lineas_marioneta',
#    'region_name': 'Comisuras / lineas de marioneta',
#    'region_alias': 'Lineas marioneta',
#    'box_index': 2,
#    'score': 0,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': False,
#    'bbox': {'x': 622, 'y': 710, 'w': 126, 'h': 190}},
#   {'order': 12,
#    'label_id': 8,
#    'region_key': 'puente_nasal',
#    'region_name': 'Puente Nasal',
#    'region_alias': 'Puente nasal',
#    'box_index': 1,
#    'score': 0,
#    'ethnicity': 'Niño joven asiatico',
#    'omitted': False,
#    'bbox': {'x': 494, 'y': 495, 'w': 69, 'h': 102}}]}
