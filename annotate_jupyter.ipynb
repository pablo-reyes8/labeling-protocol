# %%
! pip install -r requirements.txt

# %%
import sys
from pathlib import Path

SRC_DIR = Path.cwd() / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

import importlib
from envegecimiento import external_bbox_annotator, run_annotation

importlib.reload(external_bbox_annotator)
importlib.reload(run_annotation)
# Out:
# <module 'envegecimiento.run_annotation' from 'c:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\src\\envegecimiento\\run_annotation.py'>

# %%
NUM_IMAGES = 2  # cambia este numero
result = run_annotation.run(
    r"data",
    num_images=NUM_IMAGES,)

result

# %%
from envegecimiento.preview_boxes_from_json import show_boxes_from_json

result_preview = show_boxes_from_json(
    r'results\portrait-white-man-isolated_annotations.json',
    show=True,
)
result_preview
# Out:
# JSON: C:\Users\alejo\OneDrive\Escritorio\Pablo\Profesional\Semillero\protocolo de etiquetado\results\portrait-white-man-isolated_annotations.json
# Imagen original: C:\Users\alejo\OneDrive\Escritorio\Pablo\Profesional\Semillero\protocolo de etiquetado\data\portrait-white-man-isolated.jpg
# Global: {'label_id': 0, 'score': 50, 'ethnicity': 'Hombre Blanco'}
#
# Boxes en orden:
# 01. Frente#1 | score=30 | etnicidad=Hombre Blanco | bbox=(x=1750, y=897, w=1247, h=454)
# 02. Entrecejo#1 | score=25 | etnicidad=Hombre Blanco | bbox=(x=2235, y=1320, w=301, h=289)
# 03. Patas de gallo#1 | score=0 | etnicidad=Hombre Blanco | bbox=(x=1677, y=1449, w=178, h=228)
# 05. Ojeras#1 | score=20 | etnicidad=Hombre Blanco | bbox=(x=1849, y=1640, w=356, h=184)
# 07. Surcos nasogenianos#1 | score=10 | etnicidad=Hombre Blanco | bbox=(x=1935, y=1941, w=233, h=313)
# 09. Labio superior#1 | score=20 | etnicidad=Hombre Blanco | bbox=(x=1990, y=2027, w=761, h=221)
# 10. Lineas marioneta#1 | score=15 | etnicidad=Hombre Blanco | bbox=(x=1695, y=2100, w=418, h=547)
# 12. Puente nasal#1 | score=20 | etnicidad=Hombre Blanco | bbox=(x=2272, y=1542, w=283, h=343)
#
# Preview guardado en: C:\Users\alejo\OneDrive\Escritorio\Pablo\Profesional\Semillero\protocolo de etiquetado\data_boxes\portrait-white-man-isolated_boxes_preview.jpg
# {'json_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\results\\portrait-white-man-isolated_annotations.json',
#  'image_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\data\\portrait-white-man-isolated.jpg',
#  'preview_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\data_boxes\\portrait-white-man-isolated_boxes_preview.jpg',
#  'boxes': [{'order': 1,
#    'label_id': 1,
#    'region_key': 'frente',
#    'region_name': 'Frente',
#    'region_alias': 'Frente',
#    'box_index': 1,
#    'score': 30,
#    'ethnicity': 'Hombre Blanco',
#    'omitted': False,
#    'bbox': {'x': 1750, 'y': 897, 'w': 1247, 'h': 454}},
#   {'order': 2,
#    'label_id': 2,
#    'region_key': 'glabela_entrecejo',
#    'region_name': 'Glabela / Entrecejo',
#    'region_alias': 'Entrecejo',
#    'box_index': 1,
#    'score': 25,
#    'ethnicity': 'Hombre Blanco',
#    'omitted': False,
#    'bbox': {'x': 2235, 'y': 1320, 'w': 301, 'h': 289}},
#   {'order': 3,
#    'label_id': 3,
#    'region_key': 'patas_de_gallo',
#    'region_name': 'Patas de gallo',
#    'region_alias': 'Patas de gallo',
#    'box_index': 1,
#    'score': 0,
#    'ethnicity': 'Hombre Blanco',
#    'omitted': False,
#    'bbox': {'x': 1677, 'y': 1449, 'w': 178, 'h': 228}},
#   {'order': 5,
#    'label_id': 4,
#    'region_key': 'bajo_ojo_ojeras',
#    'region_name': 'Bajo ojo / Ojeras',
#    'region_alias': 'Ojeras',
#    'box_index': 1,
#    'score': 20,
#    'ethnicity': 'Hombre Blanco',
#    'omitted': False,
#    'bbox': {'x': 1849, 'y': 1640, 'w': 356, 'h': 184}},
#   {'order': 7,
#    'label_id': 5,
#    'region_key': 'surcos_nasogenianos',
#    'region_name': 'Surcos Nasogenianos',
#    'region_alias': 'Surcos nasogenianos',
#    'box_index': 1,
#    'score': 10,
#    'ethnicity': 'Hombre Blanco',
#    'omitted': False,
#    'bbox': {'x': 1935, 'y': 1941, 'w': 233, 'h': 313}},
#   {'order': 9,
#    'label_id': 6,
#    'region_key': 'labio_superior',
#    'region_name': 'Labio superior',
#    'region_alias': 'Labio superior',
#    'box_index': 1,
#    'score': 20,
#    'ethnicity': 'Hombre Blanco',
#    'omitted': False,
#    'bbox': {'x': 1990, 'y': 2027, 'w': 761, 'h': 221}},
#   {'order': 10,
#    'label_id': 7,
#    'region_key': 'comisuras_lineas_marioneta',
#    'region_name': 'Comisuras / lineas de marioneta',
#    'region_alias': 'Lineas marioneta',
#    'box_index': 1,
#    'score': 15,
#    'ethnicity': 'Hombre Blanco',
#    'omitted': False,
#    'bbox': {'x': 1695, 'y': 2100, 'w': 418, 'h': 547}},
#   {'order': 12,
#    'label_id': 8,
#    'region_key': 'puente_nasal',
#    'region_name': 'Puente Nasal',
#    'region_alias': 'Puente nasal',
#    'box_index': 1,
#    'score': 20,
#    'ethnicity': 'Hombre Blanco',
#    'omitted': False,
#    'bbox': {'x': 2272, 'y': 1542, 'w': 283, 'h': 343}}]}
