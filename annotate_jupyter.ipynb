# %%
# %pip install -r requirements.txt

# %%
import sys
from pathlib import Path

SRC_DIR = Path.cwd() / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

import importlib
from envegecimiento import external_bbox_annotator, run_annotation

importlib.reload(external_bbox_annotator)
importlib.reload(run_annotation)


result = run_annotation.run(
    "drive",
    num_images=4,
    fail_on_upload_error=False)

result
# Out:
# Sesion batch (drive_remote_session): 4 pendiente(s) de 4 total.
# [1/4] Anotando: 17133.png
# [2/4] Anotando: 27460.png
# [3/4] Anotando: 18338.png
# [4/4] Anotando: 46884.png
# {'mode': 'batch',
#  'selection': 'drive_remote_session',
#  'total_requested': 4,
#  'total_completed': 4,
#  'session_total': 4,
#  'session_resumed_from_index': 1,
#  'items': [{'image_id': '17133.png',
#    'image_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\.drive_cache\\1LN7VNGPRz6kZN5a_VvbOCkbMXG6y7F3u\\17133.png',
#    'image_meta': {'filename': '17133.png',
#     'stem': '17133',
#     'extension': '.png',
#     'file_size_bytes': 1420148,
#     'width_px': 1024,
#     'height_px': 1024,
#     'modified_at': '2026-04-02T23:48:22Z'},
#    'created_at': '2026-04-02T23:48:22Z',
#    'global': {'label_id': 0,
#     'score': 0,
#     'ethnicity': 'Hombre Blanco Americano'},
#    'regions': {'frente': {'label_id': 1,
#      'region_name': 'Frente',
#      'region_alias': 'Frente',
#      'expected_boxes': 1,
#      'slots': [{'box_index': 1,
#        'bbox': None,
#        'score': None,
#        'ethnicity': 'Hombre Blanco Americano',
#        'omitted': True,
#        'slot_status': 'Missing'}]},
#     'glabela_entrecejo': {'label_id': 2,
#      'region_name': 'Glabela / Entrecejo',
#      'region_alias': 'Entrecejo',
#      'expected_boxes': 1,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 438, 'y': 407, 'w': 125, 'h': 126},
#        'score': 0,
#        'ethnicity': 'Hombre Blanco Americano',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'patas_de_gallo': {'label_id': 3,
#      'region_name': 'Patas de gallo',
#      'region_alias': 'Patas de gallo',
#      'expected_boxes': 2,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 721, 'y': 441, 'w': 121, 'h': 97},
#        'score': 0,
#        'ethnicity': 'Hombre Blanco Americano',
#        'omitted': False,
#        'slot_status': 'Annotated'},
#       {'box_index': 2,
#        'bbox': {'x': 270, 'y': 435, 'w': 71, 'h': 104},
#        'score': 0,
#        'ethnicity': 'Hombre Blanco Americano',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'bajo_ojo_ojeras': {'label_id': 4,
#      'region_name': 'Bajo ojo / Ojeras',
#      'region_alias': 'Ojeras',
#      'expected_boxes': 2,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 316, 'y': 501, 'w': 133, 'h': 86},
#        'score': 40,
#        'ethnicity': 'Hombre Blanco Americano',
#        'omitted': False,
#        'slot_status': 'Annotated'},
#       {'box_index': 2,
#        'bbox': {'x': 566, 'y': 515, 'w': 162, 'h': 74},
#        'score': 60,
#        'ethnicity': 'Hombre Blanco Americano',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'surcos_nasogenianos': {'label_id': 5,
#      'region_name': 'Surcos Nasogenianos',
#      'region_alias': 'Surcos nasogenianos',
#      'expected_boxes': 2,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 585, 'y': 607, 'w': 211, 'h': 97},
#        'score': 0,
#        'ethnicity': 'Hombre Blanco Americano',
#        'omitted': False,
#        'slot_status': 'Annotated'},
#       {'box_index': 2,
#        'bbox': {'x': 293, 'y': 600, 'w': 131, 'h': 86},
#        'score': 0,
#        'ethnicity': 'Hombre Blanco Americano',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'labio_superior': {'label_id': 6,
#      'region_name': 'Labio superior',
#      'region_alias': 'Labio superior',
#      'expected_boxes': 1,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 384, 'y': 651, 'w': 269, 'h': 54},
#        'score': 0,
#        'ethnicity': 'Hombre Blanco Americano',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'comisuras_lineas_marioneta': {'label_id': 7,
#      'region_name': 'Comisuras / lineas de marioneta',
#      'region_alias': 'Lineas marioneta',
#      'expected_boxes': 2,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 310, 'y': 641, 'w': 127, 'h': 217},
#        'score': 0,
#        'ethnicity': 'Hombre Blanco Americano',
#        'omitted': False,
#        'slot_status': 'Annotated'},
#       {'box_index': 2,
#        'bbox': {'x': 609, 'y': 678, 'w': 166, 'h': 185},
#        'score': 0,
#        'ethnicity': 'Hombre Blanco Americano',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'puente_nasal': {'label_id': 8,
#      'region_name': 'Puente Nasal',
#      'region_alias': 'Puente nasal',
#      'expected_boxes': 1,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 454, 'y': 503, 'w': 101, 'h': 128},
#        'score': 0,
#        'ethnicity': 'Hombre Blanco Americano',
#        'omitted': False,
#        'slot_status': 'Annotated'}]}},
#    'all_slots': [{'label_id': 1,
#      'region_key': 'frente',
#      'region_name': 'Frente',
#      'region_alias': 'Frente',
#      'box_index': 1,
#      'bbox': None,
#      'score': None,
#      'ethnicity': 'Hombre Blanco Americano',
#      'omitted': True,
#      'slot_status': 'Missing'},
#     {'label_id': 2,
#      'region_key': 'glabela_entrecejo',
#      'region_name': 'Glabela / Entrecejo',
#      'region_alias': 'Entrecejo',
#      'box_index': 1,
#      'bbox': {'x': 438, 'y': 407, 'w': 125, 'h': 126},
#      'score': 0,
#      'ethnicity': 'Hombre Blanco Americano',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 3,
#      'region_key': 'patas_de_gallo',
#      'region_name': 'Patas de gallo',
#      'region_alias': 'Patas de gallo',
#      'box_index': 1,
#      'bbox': {'x': 721, 'y': 441, 'w': 121, 'h': 97},
#      'score': 0,
#      'ethnicity': 'Hombre Blanco Americano',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 3,
#      'region_key': 'patas_de_gallo',
#      'region_name': 'Patas de gallo',
#      'region_alias': 'Patas de gallo',
#      'box_index': 2,
#      'bbox': {'x': 270, 'y': 435, 'w': 71, 'h': 104},
#      'score': 0,
#      'ethnicity': 'Hombre Blanco Americano',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 4,
#      'region_key': 'bajo_ojo_ojeras',
#      'region_name': 'Bajo ojo / Ojeras',
#      'region_alias': 'Ojeras',
#      'box_index': 1,
#      'bbox': {'x': 316, 'y': 501, 'w': 133, 'h': 86},
#      'score': 40,
#      'ethnicity': 'Hombre Blanco Americano',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 4,
#      'region_key': 'bajo_ojo_ojeras',
#      'region_name': 'Bajo ojo / Ojeras',
#      'region_alias': 'Ojeras',
#      'box_index': 2,
#      'bbox': {'x': 566, 'y': 515, 'w': 162, 'h': 74},
#      'score': 60,
#      'ethnicity': 'Hombre Blanco Americano',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 5,
#      'region_key': 'surcos_nasogenianos',
#      'region_name': 'Surcos Nasogenianos',
#      'region_alias': 'Surcos nasogenianos',
#      'box_index': 1,
#      'bbox': {'x': 585, 'y': 607, 'w': 211, 'h': 97},
#      'score': 0,
#      'ethnicity': 'Hombre Blanco Americano',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 5,
#      'region_key': 'surcos_nasogenianos',
#      'region_name': 'Surcos Nasogenianos',
#      'region_alias': 'Surcos nasogenianos',
#      'box_index': 2,
#      'bbox': {'x': 293, 'y': 600, 'w': 131, 'h': 86},
#      'score': 0,
#      'ethnicity': 'Hombre Blanco Americano',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 6,
#      'region_key': 'labio_superior',
#      'region_name': 'Labio superior',
#      'region_alias': 'Labio superior',
#      'box_index': 1,
#      'bbox': {'x': 384, 'y': 651, 'w': 269, 'h': 54},
#      'score': 0,
#      'ethnicity': 'Hombre Blanco Americano',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 7,
#      'region_key': 'comisuras_lineas_marioneta',
#      'region_name': 'Comisuras / lineas de marioneta',
#      'region_alias': 'Lineas marioneta',
#      'box_index': 1,
#      'bbox': {'x': 310, 'y': 641, 'w': 127, 'h': 217},
#      'score': 0,
#      'ethnicity': 'Hombre Blanco Americano',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 7,
#      'region_key': 'comisuras_lineas_marioneta',
#      'region_name': 'Comisuras / lineas de marioneta',
#      'region_alias': 'Lineas marioneta',
#      'box_index': 2,
#      'bbox': {'x': 609, 'y': 678, 'w': 166, 'h': 185},
#      'score': 0,
#      'ethnicity': 'Hombre Blanco Americano',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 8,
#      'region_key': 'puente_nasal',
#      'region_name': 'Puente Nasal',
#      'region_alias': 'Puente nasal',
#      'box_index': 1,
#      'bbox': {'x': 454, 'y': 503, 'w': 101, 'h': 128},
#      'score': 0,
#      'ethnicity': 'Hombre Blanco Americano',
#      'omitted': False,
#      'slot_status': 'Annotated'}],
#    '_local_json_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\results\\17133_annotations.json',
#    '_batch_index': 1,
#    '_batch_total': 4,
#    '_session_total': 4,
#    '_session_resumed_from_index': 1,
#    '_upload': {'ok': True,
#     'status_code': 200,
#     'response_text': 'OK: saved 1 -> 17133.png.json',
#     'remote_filename': '17133.png.json'}},
#   {'image_id': '27460.png',
#    'image_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\.drive_cache\\1LN7VNGPRz6kZN5a_VvbOCkbMXG6y7F3u\\27460.png',
#    'image_meta': {'filename': '27460.png',
#     'stem': '27460',
#     'extension': '.png',
#     'file_size_bytes': 1353862,
#     'width_px': 1024,
#     'height_px': 1024,
#     'modified_at': '2026-04-02T23:48:34Z'},
#    'created_at': '2026-04-02T23:50:54Z',
#    'global': {'label_id': 0, 'score': 0, 'ethnicity': 'Mujer Afroamericana'},
#    'regions': {'frente': {'label_id': 1,
#      'region_name': 'Frente',
#      'region_alias': 'Frente',
#      'expected_boxes': 1,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 246, 'y': 290, 'w': 508, 'h': 118},
#        'score': 0,
#        'ethnicity': 'Mujer Afroamericana',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'glabela_entrecejo': {'label_id': 2,
#      'region_name': 'Glabela / Entrecejo',
#      'region_alias': 'Entrecejo',
#      'expected_boxes': 1,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 445, 'y': 410, 'w': 130, 'h': 129},
#        'score': 0,
#        'ethnicity': 'Mujer Afroamericana',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'patas_de_gallo': {'label_id': 3,
#      'region_name': 'Patas de gallo',
#      'region_alias': 'Patas de gallo',
#      'expected_boxes': 2,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 245, 'y': 464, 'w': 75, 'h': 78},
#        'score': 0,
#        'ethnicity': 'Mujer Afroamericana',
#        'omitted': False,
#        'slot_status': 'Annotated'},
#       {'box_index': 2,
#        'bbox': {'x': 727, 'y': 459, 'w': 85, 'h': 114},
#        'score': 0,
#        'ethnicity': 'Mujer Afroamericana',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'bajo_ojo_ojeras': {'label_id': 4,
#      'region_name': 'Bajo ojo / Ojeras',
#      'region_alias': 'Ojeras',
#      'expected_boxes': 2,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 304, 'y': 494, 'w': 140, 'h': 76},
#        'score': 30,
#        'ethnicity': 'Mujer Afroamericana',
#        'omitted': False,
#        'slot_status': 'Annotated'},
#       {'box_index': 2,
#        'bbox': {'x': 576, 'y': 505, 'w': 142, 'h': 78},
#        'score': 10,
#        'ethnicity': 'Mujer Afroamericana',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'surcos_nasogenianos': {'label_id': 5,
#      'region_name': 'Surcos Nasogenianos',
#      'region_alias': 'Surcos nasogenianos',
#      'expected_boxes': 2,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 277, 'y': 597, 'w': 131, 'h': 116},
#        'score': 0,
#        'ethnicity': 'Mujer Afroamericana',
#        'omitted': False,
#        'slot_status': 'Annotated'},
#       {'box_index': 2,
#        'bbox': {'x': 586, 'y': 592, 'w': 185, 'h': 119},
#        'score': 0,
#        'ethnicity': 'Mujer Afroamericana',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'labio_superior': {'label_id': 6,
#      'region_name': 'Labio superior',
#      'region_alias': 'Labio superior',
#      'expected_boxes': 1,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 354, 'y': 644, 'w': 333, 'h': 70},
#        'score': 0,
#        'ethnicity': 'Mujer Afroamericana',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'comisuras_lineas_marioneta': {'label_id': 7,
#      'region_name': 'Comisuras / lineas de marioneta',
#      'region_alias': 'Lineas marioneta',
#      'expected_boxes': 2,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 280, 'y': 688, 'w': 148, 'h': 177},
#        'score': 15,
#        'ethnicity': 'Mujer Afroamericana',
#        'omitted': False,
#        'slot_status': 'Annotated'},
#       {'box_index': 2,
#        'bbox': {'x': 602, 'y': 677, 'w': 165, 'h': 178},
#        'score': 15,
#        'ethnicity': 'Mujer Afroamericana',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'puente_nasal': {'label_id': 8,
#      'region_name': 'Puente Nasal',
#      'region_alias': 'Puente nasal',
#      'expected_boxes': 1,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 449, 'y': 481, 'w': 118, 'h': 111},
#        'score': 0,
#        'ethnicity': 'Mujer Afroamericana',
#        'omitted': False,
#        'slot_status': 'Annotated'}]}},
#    'all_slots': [{'label_id': 1,
#      'region_key': 'frente',
#      'region_name': 'Frente',
#      'region_alias': 'Frente',
#      'box_index': 1,
#      'bbox': {'x': 246, 'y': 290, 'w': 508, 'h': 118},
#      'score': 0,
#      'ethnicity': 'Mujer Afroamericana',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 2,
#      'region_key': 'glabela_entrecejo',
#      'region_name': 'Glabela / Entrecejo',
#      'region_alias': 'Entrecejo',
#      'box_index': 1,
#      'bbox': {'x': 445, 'y': 410, 'w': 130, 'h': 129},
#      'score': 0,
#      'ethnicity': 'Mujer Afroamericana',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 3,
#      'region_key': 'patas_de_gallo',
#      'region_name': 'Patas de gallo',
#      'region_alias': 'Patas de gallo',
#      'box_index': 1,
#      'bbox': {'x': 245, 'y': 464, 'w': 75, 'h': 78},
#      'score': 0,
#      'ethnicity': 'Mujer Afroamericana',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 3,
#      'region_key': 'patas_de_gallo',
#      'region_name': 'Patas de gallo',
#      'region_alias': 'Patas de gallo',
#      'box_index': 2,
#      'bbox': {'x': 727, 'y': 459, 'w': 85, 'h': 114},
#      'score': 0,
#      'ethnicity': 'Mujer Afroamericana',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 4,
#      'region_key': 'bajo_ojo_ojeras',
#      'region_name': 'Bajo ojo / Ojeras',
#      'region_alias': 'Ojeras',
#      'box_index': 1,
#      'bbox': {'x': 304, 'y': 494, 'w': 140, 'h': 76},
#      'score': 30,
#      'ethnicity': 'Mujer Afroamericana',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 4,
#      'region_key': 'bajo_ojo_ojeras',
#      'region_name': 'Bajo ojo / Ojeras',
#      'region_alias': 'Ojeras',
#      'box_index': 2,
#      'bbox': {'x': 576, 'y': 505, 'w': 142, 'h': 78},
#      'score': 10,
#      'ethnicity': 'Mujer Afroamericana',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 5,
#      'region_key': 'surcos_nasogenianos',
#      'region_name': 'Surcos Nasogenianos',
#      'region_alias': 'Surcos nasogenianos',
#      'box_index': 1,
#      'bbox': {'x': 277, 'y': 597, 'w': 131, 'h': 116},
#      'score': 0,
#      'ethnicity': 'Mujer Afroamericana',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 5,
#      'region_key': 'surcos_nasogenianos',
#      'region_name': 'Surcos Nasogenianos',
#      'region_alias': 'Surcos nasogenianos',
#      'box_index': 2,
#      'bbox': {'x': 586, 'y': 592, 'w': 185, 'h': 119},
#      'score': 0,
#      'ethnicity': 'Mujer Afroamericana',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 6,
#      'region_key': 'labio_superior',
#      'region_name': 'Labio superior',
#      'region_alias': 'Labio superior',
#      'box_index': 1,
#      'bbox': {'x': 354, 'y': 644, 'w': 333, 'h': 70},
#      'score': 0,
#      'ethnicity': 'Mujer Afroamericana',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 7,
#      'region_key': 'comisuras_lineas_marioneta',
#      'region_name': 'Comisuras / lineas de marioneta',
#      'region_alias': 'Lineas marioneta',
#      'box_index': 1,
#      'bbox': {'x': 280, 'y': 688, 'w': 148, 'h': 177},
#      'score': 15,
#      'ethnicity': 'Mujer Afroamericana',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 7,
#      'region_key': 'comisuras_lineas_marioneta',
#      'region_name': 'Comisuras / lineas de marioneta',
#      'region_alias': 'Lineas marioneta',
#      'box_index': 2,
#      'bbox': {'x': 602, 'y': 677, 'w': 165, 'h': 178},
#      'score': 15,
#      'ethnicity': 'Mujer Afroamericana',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 8,
#      'region_key': 'puente_nasal',
#      'region_name': 'Puente Nasal',
#      'region_alias': 'Puente nasal',
#      'box_index': 1,
#      'bbox': {'x': 449, 'y': 481, 'w': 118, 'h': 111},
#      'score': 0,
#      'ethnicity': 'Mujer Afroamericana',
#      'omitted': False,
#      'slot_status': 'Annotated'}],
#    '_local_json_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\results\\27460_annotations.json',
#    '_batch_index': 2,
#    '_batch_total': 4,
#    '_session_total': 4,
#    '_session_resumed_from_index': 1,
#    '_upload': {'ok': True,
#     'status_code': 200,
#     'response_text': 'OK: saved 1 -> 27460.png.json',
#     'remote_filename': '27460.png.json'}},
#   {'image_id': '18338.png',
#    'image_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\.drive_cache\\1LN7VNGPRz6kZN5a_VvbOCkbMXG6y7F3u\\18338.png',
#    'image_meta': {'filename': '18338.png',
#     'stem': '18338',
#     'extension': '.png',
#     'file_size_bytes': 1526661,
#     'width_px': 1024,
#     'height_px': 1024,
#     'modified_at': '2026-04-02T23:48:46Z'},
#    'created_at': '2026-04-02T23:52:23Z',
#    'global': {'label_id': 0, 'score': 10, 'ethnicity': 'Mujer Blanca'},
#    'regions': {'frente': {'label_id': 1,
#      'region_name': 'Frente',
#      'region_alias': 'Frente',
#      'expected_boxes': 1,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 265, 'y': 218, 'w': 482, 'h': 169},
#        'score': 50,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'glabela_entrecejo': {'label_id': 2,
#      'region_name': 'Glabela / Entrecejo',
#      'region_alias': 'Entrecejo',
#      'expected_boxes': 1,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 442, 'y': 378, 'w': 135, 'h': 110},
#        'score': 0,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'patas_de_gallo': {'label_id': 3,
#      'region_name': 'Patas de gallo',
#      'region_alias': 'Patas de gallo',
#      'expected_boxes': 2,
#      'slots': [{'box_index': 1,
#        'bbox': None,
#        'score': None,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': True,
#        'slot_status': 'Missing'},
#       {'box_index': 2,
#        'bbox': None,
#        'score': None,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': True,
#        'slot_status': 'Missing'}]},
#     'bajo_ojo_ojeras': {'label_id': 4,
#      'region_name': 'Bajo ojo / Ojeras',
#      'region_alias': 'Ojeras',
#      'expected_boxes': 2,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 326, 'y': 521, 'w': 136, 'h': 65},
#        'score': 0,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': False,
#        'slot_status': 'Annotated'},
#       {'box_index': 2,
#        'bbox': {'x': 579, 'y': 516, 'w': 129, 'h': 69},
#        'score': 0,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'surcos_nasogenianos': {'label_id': 5,
#      'region_name': 'Surcos Nasogenianos',
#      'region_alias': 'Surcos nasogenianos',
#      'expected_boxes': 2,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 273, 'y': 643, 'w': 172, 'h': 122},
#        'score': 0,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': False,
#        'slot_status': 'Annotated'},
#       {'box_index': 2,
#        'bbox': {'x': 579, 'y': 637, 'w': 168, 'h': 134},
#        'score': 0,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'labio_superior': {'label_id': 6,
#      'region_name': 'Labio superior',
#      'region_alias': 'Labio superior',
#      'expected_boxes': 1,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 364, 'y': 697, 'w': 289, 'h': 71},
#        'score': 0,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'comisuras_lineas_marioneta': {'label_id': 7,
#      'region_name': 'Comisuras / lineas de marioneta',
#      'region_alias': 'Lineas marioneta',
#      'expected_boxes': 2,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 246, 'y': 718, 'w': 134, 'h': 224},
#        'score': 0,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': False,
#        'slot_status': 'Annotated'},
#       {'box_index': 2,
#        'bbox': None,
#        'score': None,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': True,
#        'slot_status': 'Missing'}]},
#     'puente_nasal': {'label_id': 8,
#      'region_name': 'Puente Nasal',
#      'region_alias': 'Puente nasal',
#      'expected_boxes': 1,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 461, 'y': 509, 'w': 124, 'h': 140},
#        'score': 0,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': False,
#        'slot_status': 'Annotated'}]}},
#    'all_slots': [{'label_id': 1,
#      'region_key': 'frente',
#      'region_name': 'Frente',
#      'region_alias': 'Frente',
#      'box_index': 1,
#      'bbox': {'x': 265, 'y': 218, 'w': 482, 'h': 169},
#      'score': 50,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 2,
#      'region_key': 'glabela_entrecejo',
#      'region_name': 'Glabela / Entrecejo',
#      'region_alias': 'Entrecejo',
#      'box_index': 1,
#      'bbox': {'x': 442, 'y': 378, 'w': 135, 'h': 110},
#      'score': 0,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 3,
#      'region_key': 'patas_de_gallo',
#      'region_name': 'Patas de gallo',
#      'region_alias': 'Patas de gallo',
#      'box_index': 1,
#      'bbox': None,
#      'score': None,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': True,
#      'slot_status': 'Missing'},
#     {'label_id': 3,
#      'region_key': 'patas_de_gallo',
#      'region_name': 'Patas de gallo',
#      'region_alias': 'Patas de gallo',
#      'box_index': 2,
#      'bbox': None,
#      'score': None,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': True,
#      'slot_status': 'Missing'},
#     {'label_id': 4,
#      'region_key': 'bajo_ojo_ojeras',
#      'region_name': 'Bajo ojo / Ojeras',
#      'region_alias': 'Ojeras',
#      'box_index': 1,
#      'bbox': {'x': 326, 'y': 521, 'w': 136, 'h': 65},
#      'score': 0,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 4,
#      'region_key': 'bajo_ojo_ojeras',
#      'region_name': 'Bajo ojo / Ojeras',
#      'region_alias': 'Ojeras',
#      'box_index': 2,
#      'bbox': {'x': 579, 'y': 516, 'w': 129, 'h': 69},
#      'score': 0,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 5,
#      'region_key': 'surcos_nasogenianos',
#      'region_name': 'Surcos Nasogenianos',
#      'region_alias': 'Surcos nasogenianos',
#      'box_index': 1,
#      'bbox': {'x': 273, 'y': 643, 'w': 172, 'h': 122},
#      'score': 0,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 5,
#      'region_key': 'surcos_nasogenianos',
#      'region_name': 'Surcos Nasogenianos',
#      'region_alias': 'Surcos nasogenianos',
#      'box_index': 2,
#      'bbox': {'x': 579, 'y': 637, 'w': 168, 'h': 134},
#      'score': 0,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 6,
#      'region_key': 'labio_superior',
#      'region_name': 'Labio superior',
#      'region_alias': 'Labio superior',
#      'box_index': 1,
#      'bbox': {'x': 364, 'y': 697, 'w': 289, 'h': 71},
#      'score': 0,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 7,
#      'region_key': 'comisuras_lineas_marioneta',
#      'region_name': 'Comisuras / lineas de marioneta',
#      'region_alias': 'Lineas marioneta',
#      'box_index': 1,
#      'bbox': {'x': 246, 'y': 718, 'w': 134, 'h': 224},
#      'score': 0,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 7,
#      'region_key': 'comisuras_lineas_marioneta',
#      'region_name': 'Comisuras / lineas de marioneta',
#      'region_alias': 'Lineas marioneta',
#      'box_index': 2,
#      'bbox': None,
#      'score': None,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': True,
#      'slot_status': 'Missing'},
#     {'label_id': 8,
#      'region_key': 'puente_nasal',
#      'region_name': 'Puente Nasal',
#      'region_alias': 'Puente nasal',
#      'box_index': 1,
#      'bbox': {'x': 461, 'y': 509, 'w': 124, 'h': 140},
#      'score': 0,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': False,
#      'slot_status': 'Annotated'}],
#    '_local_json_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\results\\18338_annotations.json',
#    '_batch_index': 3,
#    '_batch_total': 4,
#    '_session_total': 4,
#    '_session_resumed_from_index': 1,
#    '_upload': {'ok': True,
#     'status_code': 200,
#     'response_text': 'OK: saved 1 -> 18338.png.json',
#     'remote_filename': '18338.png.json'}},
#   {'image_id': '46884.png',
#    'image_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\.drive_cache\\1LN7VNGPRz6kZN5a_VvbOCkbMXG6y7F3u\\46884.png',
#    'image_meta': {'filename': '46884.png',
#     'stem': '46884',
#     'extension': '.png',
#     'file_size_bytes': 1663206,
#     'width_px': 1024,
#     'height_px': 1024,
#     'modified_at': '2026-04-02T23:48:58Z'},
#    'created_at': '2026-04-02T23:53:52Z',
#    'global': {'label_id': 0, 'score': 0, 'ethnicity': 'Mujer Blanca'},
#    'regions': {'frente': {'label_id': 1,
#      'region_name': 'Frente',
#      'region_alias': 'Frente',
#      'expected_boxes': 1,
#      'slots': [{'box_index': 1,
#        'bbox': None,
#        'score': None,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': True,
#        'slot_status': 'Missing'}]},
#     'glabela_entrecejo': {'label_id': 2,
#      'region_name': 'Glabela / Entrecejo',
#      'region_alias': 'Entrecejo',
#      'expected_boxes': 1,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 464, 'y': 356, 'w': 121, 'h': 128},
#        'score': 0,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'patas_de_gallo': {'label_id': 3,
#      'region_name': 'Patas de gallo',
#      'region_alias': 'Patas de gallo',
#      'expected_boxes': 2,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 181, 'y': 424, 'w': 126, 'h': 111},
#        'score': 0,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': False,
#        'slot_status': 'Annotated'},
#       {'box_index': 2,
#        'bbox': None,
#        'score': None,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': True,
#        'slot_status': 'Missing'}]},
#     'bajo_ojo_ojeras': {'label_id': 4,
#      'region_name': 'Bajo ojo / Ojeras',
#      'region_alias': 'Ojeras',
#      'expected_boxes': 2,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 284, 'y': 503, 'w': 177, 'h': 86},
#        'score': 0,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': False,
#        'slot_status': 'Annotated'},
#       {'box_index': 2,
#        'bbox': {'x': 587, 'y': 508, 'w': 145, 'h': 78},
#        'score': 0,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'surcos_nasogenianos': {'label_id': 5,
#      'region_name': 'Surcos Nasogenianos',
#      'region_alias': 'Surcos nasogenianos',
#      'expected_boxes': 2,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 287, 'y': 607, 'w': 165, 'h': 118},
#        'score': 0,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': False,
#        'slot_status': 'Annotated'},
#       {'box_index': 2,
#        'bbox': {'x': 596, 'y': 617, 'w': 134, 'h': 113},
#        'score': 0,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'labio_superior': {'label_id': 6,
#      'region_name': 'Labio superior',
#      'region_alias': 'Labio superior',
#      'expected_boxes': 1,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 384, 'y': 636, 'w': 269, 'h': 67},
#        'score': 0,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'comisuras_lineas_marioneta': {'label_id': 7,
#      'region_name': 'Comisuras / lineas de marioneta',
#      'region_alias': 'Lineas marioneta',
#      'expected_boxes': 2,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 246, 'y': 684, 'w': 175, 'h': 199},
#        'score': 0,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': False,
#        'slot_status': 'Annotated'},
#       {'box_index': 2,
#        'bbox': {'x': 607, 'y': 684, 'w': 117, 'h': 194},
#        'score': 0,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': False,
#        'slot_status': 'Annotated'}]},
#     'puente_nasal': {'label_id': 8,
#      'region_name': 'Puente Nasal',
#      'region_alias': 'Puente nasal',
#      'expected_boxes': 1,
#      'slots': [{'box_index': 1,
#        'bbox': {'x': 486, 'y': 464, 'w': 108, 'h': 115},
#        'score': 0,
#        'ethnicity': 'Mujer Blanca',
#        'omitted': False,
#        'slot_status': 'Annotated'}]}},
#    'all_slots': [{'label_id': 1,
#      'region_key': 'frente',
#      'region_name': 'Frente',
#      'region_alias': 'Frente',
#      'box_index': 1,
#      'bbox': None,
#      'score': None,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': True,
#      'slot_status': 'Missing'},
#     {'label_id': 2,
#      'region_key': 'glabela_entrecejo',
#      'region_name': 'Glabela / Entrecejo',
#      'region_alias': 'Entrecejo',
#      'box_index': 1,
#      'bbox': {'x': 464, 'y': 356, 'w': 121, 'h': 128},
#      'score': 0,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 3,
#      'region_key': 'patas_de_gallo',
#      'region_name': 'Patas de gallo',
#      'region_alias': 'Patas de gallo',
#      'box_index': 1,
#      'bbox': {'x': 181, 'y': 424, 'w': 126, 'h': 111},
#      'score': 0,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 3,
#      'region_key': 'patas_de_gallo',
#      'region_name': 'Patas de gallo',
#      'region_alias': 'Patas de gallo',
#      'box_index': 2,
#      'bbox': None,
#      'score': None,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': True,
#      'slot_status': 'Missing'},
#     {'label_id': 4,
#      'region_key': 'bajo_ojo_ojeras',
#      'region_name': 'Bajo ojo / Ojeras',
#      'region_alias': 'Ojeras',
#      'box_index': 1,
#      'bbox': {'x': 284, 'y': 503, 'w': 177, 'h': 86},
#      'score': 0,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 4,
#      'region_key': 'bajo_ojo_ojeras',
#      'region_name': 'Bajo ojo / Ojeras',
#      'region_alias': 'Ojeras',
#      'box_index': 2,
#      'bbox': {'x': 587, 'y': 508, 'w': 145, 'h': 78},
#      'score': 0,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 5,
#      'region_key': 'surcos_nasogenianos',
#      'region_name': 'Surcos Nasogenianos',
#      'region_alias': 'Surcos nasogenianos',
#      'box_index': 1,
#      'bbox': {'x': 287, 'y': 607, 'w': 165, 'h': 118},
#      'score': 0,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 5,
#      'region_key': 'surcos_nasogenianos',
#      'region_name': 'Surcos Nasogenianos',
#      'region_alias': 'Surcos nasogenianos',
#      'box_index': 2,
#      'bbox': {'x': 596, 'y': 617, 'w': 134, 'h': 113},
#      'score': 0,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 6,
#      'region_key': 'labio_superior',
#      'region_name': 'Labio superior',
#      'region_alias': 'Labio superior',
#      'box_index': 1,
#      'bbox': {'x': 384, 'y': 636, 'w': 269, 'h': 67},
#      'score': 0,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 7,
#      'region_key': 'comisuras_lineas_marioneta',
#      'region_name': 'Comisuras / lineas de marioneta',
#      'region_alias': 'Lineas marioneta',
#      'box_index': 1,
#      'bbox': {'x': 246, 'y': 684, 'w': 175, 'h': 199},
#      'score': 0,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 7,
#      'region_key': 'comisuras_lineas_marioneta',
#      'region_name': 'Comisuras / lineas de marioneta',
#      'region_alias': 'Lineas marioneta',
#      'box_index': 2,
#      'bbox': {'x': 607, 'y': 684, 'w': 117, 'h': 194},
#      'score': 0,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': False,
#      'slot_status': 'Annotated'},
#     {'label_id': 8,
#      'region_key': 'puente_nasal',
#      'region_name': 'Puente Nasal',
#      'region_alias': 'Puente nasal',
#      'box_index': 1,
#      'bbox': {'x': 486, 'y': 464, 'w': 108, 'h': 115},
#      'score': 0,
#      'ethnicity': 'Mujer Blanca',
#      'omitted': False,
#      'slot_status': 'Annotated'}],
#    '_local_json_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\results\\46884_annotations.json',
#    '_batch_index': 4,
#    '_batch_total': 4,
#    '_session_total': 4,
#    '_session_resumed_from_index': 1,
#    '_upload': {'ok': True,
#     'status_code': 200,
#     'response_text': 'OK: saved 1 -> 46884.png.json',
#     'remote_filename': '46884.png.json'}}]}

# %%
from envegecimiento.preview_boxes_from_json import show_boxes_from_json

result_preview = show_boxes_from_json(
    r'results\46884_annotations.json',
    show=True)
result_preview
# Out:
# JSON: C:\Users\alejo\OneDrive\Escritorio\Pablo\Profesional\Semillero\protocolo de etiquetado\results\46884_annotations.json
# Imagen original: C:\Users\alejo\OneDrive\Escritorio\Pablo\Profesional\Semillero\protocolo de etiquetado\.drive_cache\1LN7VNGPRz6kZN5a_VvbOCkbMXG6y7F3u\46884.png
# Global: {'label_id': 0, 'score': 0, 'ethnicity': 'Mujer Blanca'}
#
# Boxes en orden:
# 02. Entrecejo#1 | score=0 | etnicidad=Mujer Blanca | bbox=(x=464, y=356, w=121, h=128)
# 03. Patas de gallo#1 | score=0 | etnicidad=Mujer Blanca | bbox=(x=181, y=424, w=126, h=111)
# 05. Ojeras#1 | score=0 | etnicidad=Mujer Blanca | bbox=(x=284, y=503, w=177, h=86)
# 06. Ojeras#2 | score=0 | etnicidad=Mujer Blanca | bbox=(x=587, y=508, w=145, h=78)
# 07. Surcos nasogenianos#1 | score=0 | etnicidad=Mujer Blanca | bbox=(x=287, y=607, w=165, h=118)
# 08. Surcos nasogenianos#2 | score=0 | etnicidad=Mujer Blanca | bbox=(x=596, y=617, w=134, h=113)
# 09. Labio superior#1 | score=0 | etnicidad=Mujer Blanca | bbox=(x=384, y=636, w=269, h=67)
# 10. Lineas marioneta#1 | score=0 | etnicidad=Mujer Blanca | bbox=(x=246, y=684, w=175, h=199)
# 11. Lineas marioneta#2 | score=0 | etnicidad=Mujer Blanca | bbox=(x=607, y=684, w=117, h=194)
# 12. Puente nasal#1 | score=0 | etnicidad=Mujer Blanca | bbox=(x=486, y=464, w=108, h=115)
#
# Preview guardado en: C:\Users\alejo\OneDrive\Escritorio\Pablo\Profesional\Semillero\protocolo de etiquetado\data_boxes\46884_boxes_preview.jpg
# {'json_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\results\\46884_annotations.json',
#  'image_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\.drive_cache\\1LN7VNGPRz6kZN5a_VvbOCkbMXG6y7F3u\\46884.png',
#  'preview_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\data_boxes\\46884_boxes_preview.jpg',
#  'boxes': [{'order': 2,
#    'label_id': 2,
#    'region_key': 'glabela_entrecejo',
#    'region_name': 'Glabela / Entrecejo',
#    'region_alias': 'Entrecejo',
#    'box_index': 1,
#    'score': 0,
#    'ethnicity': 'Mujer Blanca',
#    'omitted': False,
#    'bbox': {'x': 464, 'y': 356, 'w': 121, 'h': 128}},
#   {'order': 3,
#    'label_id': 3,
#    'region_key': 'patas_de_gallo',
#    'region_name': 'Patas de gallo',
#    'region_alias': 'Patas de gallo',
#    'box_index': 1,
#    'score': 0,
#    'ethnicity': 'Mujer Blanca',
#    'omitted': False,
#    'bbox': {'x': 181, 'y': 424, 'w': 126, 'h': 111}},
#   {'order': 5,
#    'label_id': 4,
#    'region_key': 'bajo_ojo_ojeras',
#    'region_name': 'Bajo ojo / Ojeras',
#    'region_alias': 'Ojeras',
#    'box_index': 1,
#    'score': 0,
#    'ethnicity': 'Mujer Blanca',
#    'omitted': False,
#    'bbox': {'x': 284, 'y': 503, 'w': 177, 'h': 86}},
#   {'order': 6,
#    'label_id': 4,
#    'region_key': 'bajo_ojo_ojeras',
#    'region_name': 'Bajo ojo / Ojeras',
#    'region_alias': 'Ojeras',
#    'box_index': 2,
#    'score': 0,
#    'ethnicity': 'Mujer Blanca',
#    'omitted': False,
#    'bbox': {'x': 587, 'y': 508, 'w': 145, 'h': 78}},
#   {'order': 7,
#    'label_id': 5,
#    'region_key': 'surcos_nasogenianos',
#    'region_name': 'Surcos Nasogenianos',
#    'region_alias': 'Surcos nasogenianos',
#    'box_index': 1,
#    'score': 0,
#    'ethnicity': 'Mujer Blanca',
#    'omitted': False,
#    'bbox': {'x': 287, 'y': 607, 'w': 165, 'h': 118}},
#   {'order': 8,
#    'label_id': 5,
#    'region_key': 'surcos_nasogenianos',
#    'region_name': 'Surcos Nasogenianos',
#    'region_alias': 'Surcos nasogenianos',
#    'box_index': 2,
#    'score': 0,
#    'ethnicity': 'Mujer Blanca',
#    'omitted': False,
#    'bbox': {'x': 596, 'y': 617, 'w': 134, 'h': 113}},
#   {'order': 9,
#    'label_id': 6,
#    'region_key': 'labio_superior',
#    'region_name': 'Labio superior',
#    'region_alias': 'Labio superior',
#    'box_index': 1,
#    'score': 0,
#    'ethnicity': 'Mujer Blanca',
#    'omitted': False,
#    'bbox': {'x': 384, 'y': 636, 'w': 269, 'h': 67}},
#   {'order': 10,
#    'label_id': 7,
#    'region_key': 'comisuras_lineas_marioneta',
#    'region_name': 'Comisuras / lineas de marioneta',
#    'region_alias': 'Lineas marioneta',
#    'box_index': 1,
#    'score': 0,
#    'ethnicity': 'Mujer Blanca',
#    'omitted': False,
#    'bbox': {'x': 246, 'y': 684, 'w': 175, 'h': 199}},
#   {'order': 11,
#    'label_id': 7,
#    'region_key': 'comisuras_lineas_marioneta',
#    'region_name': 'Comisuras / lineas de marioneta',
#    'region_alias': 'Lineas marioneta',
#    'box_index': 2,
#    'score': 0,
#    'ethnicity': 'Mujer Blanca',
#    'omitted': False,
#    'bbox': {'x': 607, 'y': 684, 'w': 117, 'h': 194}},
#   {'order': 12,
#    'label_id': 8,
#    'region_key': 'puente_nasal',
#    'region_name': 'Puente Nasal',
#    'region_alias': 'Puente nasal',
#    'box_index': 1,
#    'score': 0,
#    'ethnicity': 'Mujer Blanca',
#    'omitted': False,
#    'bbox': {'x': 486, 'y': 464, 'w': 108, 'h': 115}}]}
