# %%
! pip install -r requirements.txt

# %%
import sys
from pathlib import Path

SRC_DIR = Path.cwd() / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

import importlib
from envegecimiento import external_bbox_annotator, run_annotation

importlib.reload(external_bbox_annotator)
importlib.reload(run_annotation)

NUM_IMAGES = 2  # cambia este numero
result = run_annotation.run(
    r"data",
    num_images=NUM_IMAGES,)

result

# %%
from envegecimiento.preview_boxes_from_json import show_boxes_from_json

result_preview = show_boxes_from_json(
    r'results\smiling-businessman-face-portrait-wearing-suit_annotations.json',
    show=True,
)
result_preview
# Out:
# JSON: C:\Users\alejo\OneDrive\Escritorio\Pablo\Profesional\Semillero\protocolo de etiquetado\results\smiling-businessman-face-portrait-wearing-suit_annotations.json
# Imagen original: C:\Users\alejo\OneDrive\Escritorio\Pablo\Profesional\Semillero\protocolo de etiquetado\data\smiling-businessman-face-portrait-wearing-suit.jpg
# Global: {'label_id': 0, 'score': 40, 'ethnicity': 'Hombre Moreno Americano'}
#
# Boxes en orden:
# 01. Frente#1 | score=30 | etnicidad=Hombre Moreno Americano | bbox=(x=1042, y=279, w=901, h=452)
# 02. Entrecejo#1 | score=15 | etnicidad=Hombre Moreno Americano | bbox=(x=1400, y=687, w=185, h=228)
# 03. Patas de gallo#1 | score=45 | etnicidad=Hombre Moreno Americano | bbox=(x=883, y=861, w=170, h=232)
# 05. Ojeras#1 | score=35 | etnicidad=Hombre Moreno Americano | bbox=(x=1046, y=1002, w=322, h=181)
# 07. Surcos nasogenianos#1 | score=45 | etnicidad=Hombre Moreno Americano | bbox=(x=1027, y=1245, w=290, h=253)
# 08. Surcos nasogenianos#2 | score=45 | etnicidad=Hombre Moreno Americano | bbox=(x=1682, y=1194, w=293, h=275)
# 09. Labio superior#1 | score=4 | etnicidad=Hombre Moreno Americano | bbox=(x=1169, y=1339, w=669, h=115)
# 10. Lineas marioneta#1 | score=45 | etnicidad=Hombre Moreno Americano | bbox=(x=915, y=1353, w=319, h=543)
# 11. Lineas marioneta#2 | score=45 | etnicidad=Hombre Moreno Americano | bbox=(x=1780, y=1313, w=195, h=561)
# 12. Puente nasal#1 | score=30 | etnicidad=Hombre Moreno Americano | bbox=(x=1411, y=857, w=188, h=283)
#
# Preview guardado en: C:\Users\alejo\OneDrive\Escritorio\Pablo\Profesional\Semillero\protocolo de etiquetado\data_boxes\smiling-businessman-face-portrait-wearing-suit_boxes_preview.jpg
# {'json_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\results\\smiling-businessman-face-portrait-wearing-suit_annotations.json',
#  'image_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\data\\smiling-businessman-face-portrait-wearing-suit.jpg',
#  'preview_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\Pablo\\Profesional\\Semillero\\protocolo de etiquetado\\data_boxes\\smiling-businessman-face-portrait-wearing-suit_boxes_preview.jpg',
#  'boxes': [{'order': 1,
#    'label_id': 1,
#    'region_key': 'frente',
#    'region_name': 'Frente',
#    'region_alias': 'Frente',
#    'box_index': 1,
#    'score': 30,
#    'ethnicity': 'Hombre Moreno Americano',
#    'omitted': False,
#    'bbox': {'x': 1042, 'y': 279, 'w': 901, 'h': 452}},
#   {'order': 2,
#    'label_id': 2,
#    'region_key': 'glabela_entrecejo',
#    'region_name': 'Glabela / Entrecejo',
#    'region_alias': 'Entrecejo',
#    'box_index': 1,
#    'score': 15,
#    'ethnicity': 'Hombre Moreno Americano',
#    'omitted': False,
#    'bbox': {'x': 1400, 'y': 687, 'w': 185, 'h': 228}},
#   {'order': 3,
#    'label_id': 3,
#    'region_key': 'patas_de_gallo',
#    'region_name': 'Patas de gallo',
#    'region_alias': 'Patas de gallo',
#    'box_index': 1,
#    'score': 45,
#    'ethnicity': 'Hombre Moreno Americano',
#    'omitted': False,
#    'bbox': {'x': 883, 'y': 861, 'w': 170, 'h': 232}},
#   {'order': 5,
#    'label_id': 4,
#    'region_key': 'bajo_ojo_ojeras',
#    'region_name': 'Bajo ojo / Ojeras',
#    'region_alias': 'Ojeras',
#    'box_index': 1,
#    'score': 35,
#    'ethnicity': 'Hombre Moreno Americano',
#    'omitted': False,
#    'bbox': {'x': 1046, 'y': 1002, 'w': 322, 'h': 181}},
#   {'order': 7,
#    'label_id': 5,
#    'region_key': 'surcos_nasogenianos',
#    'region_name': 'Surcos Nasogenianos',
#    'region_alias': 'Surcos nasogenianos',
#    'box_index': 1,
#    'score': 45,
#    'ethnicity': 'Hombre Moreno Americano',
#    'omitted': False,
#    'bbox': {'x': 1027, 'y': 1245, 'w': 290, 'h': 253}},
#   {'order': 8,
#    'label_id': 5,
#    'region_key': 'surcos_nasogenianos',
#    'region_name': 'Surcos Nasogenianos',
#    'region_alias': 'Surcos nasogenianos',
#    'box_index': 2,
#    'score': 45,
#    'ethnicity': 'Hombre Moreno Americano',
#    'omitted': False,
#    'bbox': {'x': 1682, 'y': 1194, 'w': 293, 'h': 275}},
#   {'order': 9,
#    'label_id': 6,
#    'region_key': 'labio_superior',
#    'region_name': 'Labio superior',
#    'region_alias': 'Labio superior',
#    'box_index': 1,
#    'score': 4,
#    'ethnicity': 'Hombre Moreno Americano',
#    'omitted': False,
#    'bbox': {'x': 1169, 'y': 1339, 'w': 669, 'h': 115}},
#   {'order': 10,
#    'label_id': 7,
#    'region_key': 'comisuras_lineas_marioneta',
#    'region_name': 'Comisuras / lineas de marioneta',
#    'region_alias': 'Lineas marioneta',
#    'box_index': 1,
#    'score': 45,
#    'ethnicity': 'Hombre Moreno Americano',
#    'omitted': False,
#    'bbox': {'x': 915, 'y': 1353, 'w': 319, 'h': 543}},
#   {'order': 11,
#    'label_id': 7,
#    'region_key': 'comisuras_lineas_marioneta',
#    'region_name': 'Comisuras / lineas de marioneta',
#    'region_alias': 'Lineas marioneta',
#    'box_index': 2,
#    'score': 45,
#    'ethnicity': 'Hombre Moreno Americano',
#    'omitted': False,
#    'bbox': {'x': 1780, 'y': 1313, 'w': 195, 'h': 561}},
#   {'order': 12,
#    'label_id': 8,
#    'region_key': 'puente_nasal',
#    'region_name': 'Puente Nasal',
#    'region_alias': 'Puente nasal',
#    'box_index': 1,
#    'score': 30,
#    'ethnicity': 'Hombre Moreno Americano',
#    'omitted': False,
#    'bbox': {'x': 1411, 'y': 857, 'w': 188, 'h': 283}}]}
